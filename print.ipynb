# %%
import importlib
import sys
from pathlib import Path

PROJECT_ROOT = Path(r"D:\\Multi_agent")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import graph.nodes.speaker_node
import graph.nodes.rag_node
import graph.workflow

importlib.reload(graph.nodes.speaker_node)
importlib.reload(graph.nodes.rag_node)
importlib.reload(graph.workflow)

from graph.workflow import build_live_assist_graph

graph = build_live_assist_graph()
print(graph.get_graph().draw_mermaid())
graph
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	speaker_node(speaker_node)
# 	rag_node(rag_node)
# 	stage_node(stage_node)
# 	checklist_node(checklist_node)
# 	stage_pitch_node(stage_pitch_node)
# 	question_node(question_node)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> speaker_node;
# 	checklist_node -.-> question_node;
# 	checklist_node -.-> stage_pitch_node;
# 	rag_node --> stage_node;
# 	speaker_node -.-> rag_node;
# 	speaker_node -.-> stage_node;
# 	stage_node --> checklist_node;
# 	question_node --> __end__;
# 	stage_pitch_node --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
from IPython.display import Image, display

png = graph.get_graph().draw_mermaid_png()
output_path = PROJECT_ROOT / "output.png"
output_path.write_bytes(png)

print(f"Saved current graph image to {output_path}")
display(Image(filename=str(output_path)))
# Out:
# Saved current graph image to D:\Multi_agent\output.png
